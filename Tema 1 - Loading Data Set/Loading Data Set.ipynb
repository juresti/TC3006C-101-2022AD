# %% [markdown]
# #Connect To Google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive

drive.mount("/content/gdrive")  
# !pwd
# Out:
# Mounted at /content/gdrive
# /content

# %% [markdown]
# Move to folder

# %%
#put your own path in google drive
# %cd "/content/gdrive/MyDrive/Cursos Tec 21/Computacion/TC3006C - Concentracion IA avanzada/Diapositivas/Datasets diapositivas"
# !ls
# Out:
# /content/gdrive/MyDrive/Cursos Tec 21/Computacion/TC3006C - Concentracion IA avanzada/Diapositivas/Datasets diapositivas
# iris.data  iris.names

# %% [markdown]
# # Load Dataset
#
# dataframe (df) is the object where pandas stores the data, each colum is actualy a hash containing the name of the column a as a key and the array of values as the value for the key

# %%
import pandas as pd

# The file has no names for columns.
columns = ["sepal length","sepal width","petal length","petal width", "class"]
df = pd.read_csv('iris.data',names = columns)
df.head()
# Out:
#    sepal length  sepal width  petal length  petal width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.columns
# Out:
# Index(['sepal length', 'sepal width', 'petal length', 'petal width', 'class'], dtype='object')

# %% [markdown]
# get a single column you wish

# %%
df["sepal length"]
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal length, Length: 150, dtype: float64

# %% [markdown]
# get many columns

# %%
df[["sepal length","sepal width"]].head()
# Out:
#    sepal length  sepal width
# 0           5.1          3.5
# 1           4.9          3.0
# 2           4.7          3.2
# 3           4.6          3.1
# 4           5.0          3.6

# %%
df_x = df[["sepal length","sepal width","petal length","petal width"]]
df_y = df[["class"]]

# %%
df_x.head()
# Out:
#    sepal length  sepal width  petal length  petal width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df_y.head()
# Out:
#          class
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %% [markdown]
# make new columns with indicators

# %%
df_x["sepal proportion"] = df_x["sepal width"]/df_x["sepal length"]
df_x["petal proportion"] = df_x["petal width"]/df_x["petal length"]
df_x.head()
# Out:
#    sepal length  sepal width  petal length  petal width  sepal proportion  \
# 0           5.1          3.5           1.4          0.2          0.686275
# 1           4.9          3.0           1.4          0.2          0.612245
# 2           4.7          3.2           1.3          0.2          0.680851
# 3           4.6          3.1           1.5          0.2          0.673913
# 4           5.0          3.6           1.4          0.2          0.720000
#
#    petal proportion
# 0          0.142857
# 1          0.142857
# 2          0.153846
# 3          0.133333
# 4          0.142857
